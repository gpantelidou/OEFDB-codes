# %%
import pandas as pd

# %%
df = pd.read_excel("SupplyChainEmissionFactorsforUSIndustriesCommodities v1.1.xlsx", sheet_name="2016_Detail_Commodity")

# %%
df
# Out:
#      Commodity Code                                     Commodity Name  \
# 0            1111A0  Fresh soybeans, canola, flaxseeds, and other o...
# 1            1111A0  Fresh soybeans, canola, flaxseeds, and other o...
# 2            1111A0  Fresh soybeans, canola, flaxseeds, and other o...
# 3            1111A0  Fresh soybeans, canola, flaxseeds, and other o...
# 4            1111B0          Fresh wheat, corn, rice, and other grains
# ...             ...                                                ...
# 1571         813B00  Civic, social, professional, and similar organ...
# 1572         814000                                Household employees
# 1573         814000                                Household employees
# 1574         814000                                Household employees
# 1575         814000                                Household employees
#
#            Substance                               Unit  \
# 0     Carbon dioxide       kg/2018 USD, purchaser price
# ...

# %%
df_carbon = df[df["Substance"] == "Carbon dioxide"]
df_methane = df[df["Substance"] == "Methane"]
df_no = df[df["Substance"] == "Nitrous oxide"]
df_other = df[df["Substance"] == "other GHGs"]

# %%
display(df_carbon)
# Out:
#      Commodity Code                                     Commodity Name  \
# 0            1111A0  Fresh soybeans, canola, flaxseeds, and other o...
# 4            1111B0          Fresh wheat, corn, rice, and other grains
# 8            111200             Fresh vegetables, melons, and potatoes
# 12           111300                         Fresh fruits and tree nuts
# 16           111400  Greenhouse crops, mushrooms, nurseries, and fl...
# ...             ...                                                ...
# 1556         812900  Pet care, photofinishing, parking and other su...
# 1560         813100                            Religious organizations
# 1564         813A00  Grantmaking, giving, and social advocacy organ...
# 1568         813B00  Civic, social, professional, and similar organ...
# 1572         814000                                Household employees
#
#            Substance                          Unit  \
# 0     Carbon dioxide  kg/2018 USD, purchaser price
# ...

# %%
GHG_df = pd.DataFrame(columns=["Commodity  Name", "Carbon Dioxide", "Methane", "Nitrous Oxide", "other GHGs"])

# %%
GHG_df
# Out:
# Empty DataFrame
# Columns: [Commodity  Name, Carbon Dioxide, Methane, Nitrous Oxide, other GHGs]
# Index: []

# %%
GHG_df = pd.DataFrame(columns=["Commodity Code", "Carbon Dioxide", "Methane", "Nitrous Oxide", "other GHGs"])
for i in range(len(df_carbon)):
    temp_values = {"Commodity Code" : df_carbon["Commodity Name"].iloc[i],
                   "Carbon Dioxide" : df_carbon["Supply Chain Emission Factors with Margins"].iloc[i],
                   "Methane" : df_methane['Supply Chain Emission Factors with Margins'].iloc[i],
                   "Nitrous Oxide" : df_no['Supply Chain Emission Factors with Margins'].iloc[i],
                   "other GHGs" : df_other['Supply Chain Emission Factors with Margins'].iloc[i]}
    GHG_df = GHG_df.append(temp_values, ignore_index=True)

# %%
GHG_df
# Out:
#                                         Commodity Code  Carbon Dioxide  \
# 0    Fresh soybeans, canola, flaxseeds, and other o...           0.679
# 1            Fresh wheat, corn, rice, and other grains           1.609
# 2               Fresh vegetables, melons, and potatoes           0.292
# 3                           Fresh fruits and tree nuts           0.271
# 4    Greenhouse crops, mushrooms, nurseries, and fl...           0.716
# ..                                                 ...             ...
# 389  Pet care, photofinishing, parking and other su...           0.108
# 390                            Religious organizations           0.196
# 391  Grantmaking, giving, and social advocacy organ...           0.067
# 392  Civic, social, professional, and similar organ...           0.122
# 393                                Household employees           0.000
#
#      Methane  Nitrous Oxide  other GHGs
# 0      0.003          0.003       0.003
# ...

# %%
#pivoted = df.pivot(index="Commodity Name", columns="Substance", values="Supply Chain Emission Factors with Margins")
#pivoted

# %%
task = pd.ExcelWriter('EPA-spend-based-task-updated.xlsx')
GHG_df.to_excel(task)
task.save()
print('DataFrame is written successfully to Excel file.')
# Out:
# DataFrame is written successfully to Excel file.
